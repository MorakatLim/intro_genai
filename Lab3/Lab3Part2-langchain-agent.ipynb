# %% [markdown]
# ## Lab 3 Part 2 - EECE.4860/5860 at UMass Lowell
#
# Complete the missing code to create a new tool based on RAG, and execute a complex query that invokes the tools.
#
# This example uses LangChain APIs.

# %%
# %pip install --upgrade langchain langgraph langchain-community langchain-huggingface langchain_openai wikipedia numexpr pypdf
# Out:
# Requirement already satisfied: langchain in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (1.2.15)
# Requirement already satisfied: langgraph in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (1.1.6)
# Requirement already satisfied: langchain-community in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (0.4.1)
# Requirement already satisfied: langchain-huggingface in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (1.2.1)
# Requirement already satisfied: langchain_openai in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (1.1.12)
# Requirement already satisfied: wikipedia in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (1.4.0)
# Requirement already satisfied: numexpr in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (2.14.1)
# Requirement already satisfied: pypdf in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (6.10.0)
# Requirement already satisfied: langchain-core<2.0.0,>=1.2.10 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from langchain) (1.2.28)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from langchain) (2.12.5)
# Requirement already satisfied: langgraph-checkpoint<5.0.0,>=2.1.0 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from langgraph) (4.0.1)
# Requirement already satisfied: langgraph-prebuilt<1.1.0,>=1.0.9 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from langgraph) (1.0.9)
# Requirement already satisfied: langgraph-sdk<0.4.0,>=0.3.0 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from langgraph) (0.3.13)
# Requirement already satisfied: xxhash>=3.5.0 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from langgraph) (3.6.0)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (0.7.30)
# Requirement already satisfied: packaging>=23.2.0 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (25.0)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (9.1.4)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (0.14.1)
# Requirement already satisfied: jsonpointer>=1.9 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.2.10->langchain) (3.0.0)
# Requirement already satisfied: ormsgpack>=1.12.0 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from langgraph-checkpoint<5.0.0,>=2.1.0->langgraph) (1.12.2)
# Requirement already satisfied: httpx>=0.25.2 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph) (0.28.1)
# Requirement already satisfied: orjson>=3.11.5 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph) (3.11.8)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain) (2.32.5)
# Requirement already satisfied: zstandard>=0.23.0 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain) (0.25.0)
# Requirement already satisfied: anyio in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph) (4.12.1)
# Requirement already satisfied: certifi in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph) (1.0.9)
# Requirement already satisfied: idna in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph) (3.11)
# Requirement already satisfied: h11>=0.16 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.2)
# Requirement already satisfied: langchain-classic<2.0.0,>=1.0.0 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from langchain-community) (1.0.3)
# Requirement already satisfied: SQLAlchemy<3.0.0,>=1.4.0 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from langchain-community) (2.0.49)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from langchain-community) (3.13.3)
# Requirement already satisfied: dataclasses-json<0.7.0,>=0.6.7 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from langchain-community) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.10.1 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from langchain-community) (2.13.1)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from langchain-community) (0.4.3)
# Requirement already satisfied: numpy>=1.26.2 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from langchain-community) (2.4.1)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.22.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community) (3.26.2)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community) (0.9.0)
# Requirement already satisfied: langchain-text-splitters<2.0.0,>=1.1.1 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from langchain-classic<2.0.0,>=1.0.0->langchain-community) (1.1.1)
# Requirement already satisfied: python-dotenv>=0.21.0 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain-community) (1.2.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain) (2.6.3)
# Requirement already satisfied: greenlet>=1 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from SQLAlchemy<3.0.0,>=1.4.0->langchain-community) (3.4.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7.0,>=0.6.7->langchain-community) (1.1.0)
# Requirement already satisfied: huggingface-hub<2.0.0,>=0.33.4 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from langchain-huggingface) (0.36.0)
# Requirement already satisfied: tokenizers<1.0.0,>=0.19.1 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from langchain-huggingface) (0.22.2)
# Requirement already satisfied: filelock in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from huggingface-hub<2.0.0,>=0.33.4->langchain-huggingface) (3.20.3)
# Requirement already satisfied: fsspec>=2023.5.0 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from huggingface-hub<2.0.0,>=0.33.4->langchain-huggingface) (2025.10.0)
# Requirement already satisfied: tqdm>=4.42.1 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from huggingface-hub<2.0.0,>=0.33.4->langchain-huggingface) (4.67.1)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from huggingface-hub<2.0.0,>=0.33.4->langchain-huggingface) (1.2.0)
# Requirement already satisfied: openai<3.0.0,>=2.26.0 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from langchain_openai) (2.31.0)
# Requirement already satisfied: tiktoken<1.0.0,>=0.7.0 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from langchain_openai) (0.12.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from openai<3.0.0,>=2.26.0->langchain_openai) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.10.0 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from openai<3.0.0,>=2.26.0->langchain_openai) (0.14.0)
# Requirement already satisfied: sniffio in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from openai<3.0.0,>=2.26.0->langchain_openai) (1.3.1)
# Requirement already satisfied: regex>=2022.1.18 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from tiktoken<1.0.0,>=0.7.0->langchain_openai) (2025.11.3)
# Requirement already satisfied: beautifulsoup4 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from wikipedia) (4.14.3)
# Requirement already satisfied: soupsieve>=1.6.1 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from beautifulsoup4->wikipedia) (2.8.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
from langchain_core.tools import tool

@tool
def magic_function(input: int) -> int:
    """Applies a magic function to an input."""
    return input + 2

tools = [magic_function]

query = "what is the value of magic_function(3)?"

# %%
from typing import Annotated
from langchain_core.tools import tool
from langchain_community.document_loaders import PyPDFLoader
from langchain_classic.text_splitter import RecursiveCharacterTextSplitter
from langchain_classic.indexes import VectorstoreIndexCreator
from langchain_huggingface import HuggingFaceEmbeddings

top_k = 1
chunk_size=2000
overlap=200

# The new tool you need to create is a RAG tool that answer queries about DeepSeek-R1
# The tool leverages a few APIs that you see in the simple_rag.ipynb example, including
# RecursiveCharacterTextSplitter(), VectorstoreIndexCreator(), vectorstore.similarity_search()
#
loader = PyPDFLoader("https://arxiv.org/pdf/2501.12948")
docs = loader.load()
# TODO: call  RecursiveCharacterTextSplitter() using chunk_size and overlap
# text_splitter = ...
text_splitter = RecursiveCharacterTextSplitter(chunk_size=chunk_size, chunk_overlap=overlap)

# TODO: create the vector database by calling VectorstoreIndexCreator()
# TODO: using HuggingFaceEmbedding() and "intfloat/multilingual-e5-large-instruct" model
#index = VectorstoreIndexCreator(
#    embedding= ...,
#    text_splitter=...
#).from_loaders([loader])

embeddings = HuggingFaceEmbeddings(
    model_name="intfloat/multilingual-e5-large-instruct",
    model_kwargs={'device': 'cpu'} 
)

index = VectorstoreIndexCreator(
    embedding=embeddings,
    text_splitter=text_splitter
).from_loaders([loader])


@tool
def query_deepseek_r1_paper(input: Annotated[str, "Query relating to DeepSeek-R1"]) -> str:
    """Provides context that can be used to answer questions on DeepSeek-R1"""
    
    print(f"Received input query: {input}\n")

    # TODO: perform similarity search on the input and top_k
    # results = ...
    results = index.vectorstore.similarity_search(input, k=top_k)
    
    if not results:
        print("No results found for the query.\n\n")
        return "no results"
    
    # TODO: concatenate the results using "\n" as a separator
    # context = 
    context = "\n".join([document.page_content for document in results])

    if context:
        print(f"Context found:\n{context}\n\n")
        
    return context
# Out:
# /tmp/ipykernel_164853/2177296639.py:34: UserWarning: Using InMemoryVectorStore as the default vectorstore.This memory store won't persist data. You should explicitlyspecify a VectorStore when using VectorstoreIndexCreator
#   index = VectorstoreIndexCreator(

# %%
# We will use an OpenAI model hosted by Jetstream2 for our agent (an API key is not needed when running on a Jetstream2 instance)
from langchain_openai import ChatOpenAI

model = ChatOpenAI(base_url="http://llm.jetstream-cloud.org/gpt-oss-120b/v1/",
                   model="gpt-oss-120b",
                   api_key="empty",
                   temperature=0.1,
                   max_tokens=1000,
                   timeout=30)

# %%
from langchain_community.utilities import WikipediaAPIWrapper
from langchain_community.tools import WikipediaQueryRun
import numexpr as ne


api_wrapper = WikipediaAPIWrapper(
    top_k_results=1,
    doc_content_chars_max=1000
)
wikipedia_tool = WikipediaQueryRun(api_wrapper=api_wrapper)

@tool
def calculator(expression: str) -> str:
    """A tool for solving mathematical problems. Input must be a mathematical expression in Python syntax."""
    print(expression)
    print(ne.evaluate(expression).item())
    return str(ne.evaluate(expression).item())

tools=[wikipedia_tool, calculator, magic_function, query_deepseek_r1_paper]

# %%
# for some reason I can't use the original imports and had to revert to the deprecated import - not sure what happened
#from langchain.agents import create_agent
from langgraph.prebuilt import create_react_agent
#agent = create_agent(llm_nvidia, tools)
agent = create_react_agent(model, tools)

# Increase the recursion limit in the configuration
config = {
   "recursion_limit": 20  # Increase the limit as needed
}

query1 = "In what year was the film Departed with Leopnardo Dicaprio released? What is this year raised to the power of 0.43?"

query2 = "Use the year the film Departed with Leopnardo Dicaprio was released to calculate the value of magic_function."

query3 = "What are the main limitations of DeepSeek-R1?"

messages1 = agent.invoke({"messages": [("human", query1)]}, config=config)

print('-'*200)
print("Query 1:", query1)
print('-'*200)
print("Response 1:", messages1["messages"][-1].content)
print('-'*200, '\n')

messages2 = agent.invoke({"messages": [("human", query2)]}, config=config)
print('-'*200)
print("Query 2:", query2)
print('-'*200)
print("Response 2:", messages2["messages"][-1].content)
print('-'*200, '\n')


messages3 = agent.invoke({"messages": [("human", query3)]}, config=config)
print('-'*200)
print("Query 3:", query3)
print('-'*200)
print("Response 3:", messages3["messages"][-1].content)
print('-'*200, '\n')
# Out:
# /tmp/ipykernel_164853/2662843843.py:4: LangGraphDeprecatedSinceV10: create_react_agent has been moved to `langchain.agents`. Please update your import to `from langchain.agents import create_agent`. Deprecated in LangGraph V1.0 to be removed in V2.0.
#   agent = create_react_agent(model, tools)
# 2006**0.43
# 26.30281917656938
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Query 1: In what year was the film Departed with Leopnardo Dicaprio released? What is this year raised to the power of 0.43?
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Response 1: The film **“The Departed”** starring Leonardo DiCaprio was released in **2006**.
#
# Raising that year to the power of 0.43:
#
# \[
# 2006^{0.43} \approx 26.30
# \]
#
# So, \(2006^{0.43} \approx \mathbf{26.3}\).
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Query 2: Use the year the film Departed with Leopnardo Dicaprio was released to calculate the value of magic_function.
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Response 2: The film *The Departed* was released in 2006.
# Passing that year to the provided `magic_function` yields:
#
# **Result: 2008**.
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#
# Received input query: What are the main limitations of DeepSeek-R1?
#
# Context found:
# capability limitations, as outlined below:
# Structure Output and Tool Use:Currently, the structural output capabilities of DeepSeek-R1
# remain suboptimal compared to existing models. Moreover, DeepSeek-R1 cannot leverage tools,
# such as search engines and calculators, to improve the performance of output. However, as it is
# not hard to build an RL environment for structure output and tool use, we believe the issue will
# be addressed in the next version.
# Token efficiency:Unlike conventional test-time computation scaling approaches, such
# as majority voting or Monte Carlo Tree Search (MCTS), DeepSeek-R1 dynamically allocates
# computational resources during inference according to the complexity of the problem at hand.
# Specifically, it uses fewer tokens to solve simple tasks, while generating more tokens for complex
# tasks. Nevertheless, there remains room for further optimization in terms of token efficiency, as
# instances of excessive reasoning—manifested as overthinking—are still observed in response to
# simpler questions.
# Language Mixing:DeepSeek-R1 is currently optimized for Chinese and English, which
# may result in language mixing issues when handling queries in other languages. For instance,
# DeepSeek-R1 might use English for reasoning and responses, even if the query is in a language
# other than English or Chinese. We aim to address this limitation in future updates. The limitation
# may be related to the base checkpoint, DeepSeek-V3-Base, mainly utilizes Chinese and English,
# so that it can achieve better results with the two languages in reasoning.
# Prompting Engineering:When evaluating DeepSeek-R1, we observe that it is sensitive to
# 10
#
#
# Received input query: DeepSeek-R1 limitations prompting engineering
#
# Context found:
# capability limitations, as outlined below:
# Structure Output and Tool Use:Currently, the structural output capabilities of DeepSeek-R1
# remain suboptimal compared to existing models. Moreover, DeepSeek-R1 cannot leverage tools,
# such as search engines and calculators, to improve the performance of output. However, as it is
# not hard to build an RL environment for structure output and tool use, we believe the issue will
# be addressed in the next version.
# Token efficiency:Unlike conventional test-time computation scaling approaches, such
# as majority voting or Monte Carlo Tree Search (MCTS), DeepSeek-R1 dynamically allocates
# computational resources during inference according to the complexity of the problem at hand.
# Specifically, it uses fewer tokens to solve simple tasks, while generating more tokens for complex
# tasks. Nevertheless, there remains room for further optimization in terms of token efficiency, as
# instances of excessive reasoning—manifested as overthinking—are still observed in response to
# simpler questions.
# Language Mixing:DeepSeek-R1 is currently optimized for Chinese and English, which
# may result in language mixing issues when handling queries in other languages. For instance,
# DeepSeek-R1 might use English for reasoning and responses, even if the query is in a language
# other than English or Chinese. We aim to address this limitation in future updates. The limitation
# may be related to the base checkpoint, DeepSeek-V3-Base, mainly utilizes Chinese and English,
# so that it can achieve better results with the two languages in reasoning.
# Prompting Engineering:When evaluating DeepSeek-R1, we observe that it is sensitive to
# 10
#
#
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Query 3: What are the main limitations of DeepSeek-R1?
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Response 3: **Main limitations of DeepSeek‑R1 (as reported by the authors)**
#
# | Area | What the model struggles with | Why it matters |
# |------|------------------------------|----------------|
# | **Structured output & tool use** | • Generates tables, JSON, code blocks, or other “structured” text less reliably than leading competitors.<br>• Cannot call external tools (search engines, calculators, APIs, etc.) during inference. | Structured data is essential for many downstream tasks (e.g., data extraction, reasoning with external knowledge, program synthesis). The lack of tool‑use also caps performance on tasks that benefit from up‑to‑date information or precise calculations. |
# | **Token‑efficiency / “over‑thinking”** | • Dynamically allocates more tokens for hard problems and fewer for easy ones, but the allocation is still imperfect. <br>• Frequently produces unnecessarily long reasoning chains on simple questions (over‑thinking) and sometimes truncates reasoning on harder ones. | Inefficient token usage raises inference cost and can degrade answer quality (either by wasting compute or by cutting off needed reasoning). |
# | **Language mixing** | • Optimized primarily for Chinese and English. When presented with other languages (e.g., Spanish, French, Arabic) the model often switches to English for its internal reasoning or final answer, producing mixed‑language outputs. | Limits the model’s usefulness in multilingual settings and can confuse users who expect a consistent language response. |
# | **Prompt‑sensitivity (prompt engineering)** | • Performance varies noticeably with small changes in prompt phrasing, temperature, or system messages. <br>• Some prompts that work well for other LLMs lead to degraded accuracy or hallucinations in DeepSeek‑R1. | Makes it harder to build robust applications; developers must spend extra effort fine‑tuning prompts or building prompt‑robustness layers. |
# | **(Implicit) Safety & Hallucination** | • The paper does not claim breakthroughs in factual grounding or safety; the same issues that affect other large language models (e.g., occasional factual errors, biased outputs) are still present. | Important for production use, especially in high‑stakes domains. |
#
# ### TL;DR
# DeepSeek‑R1 is a strong Chinese‑English reasoning model, but it still lags behind state‑of‑the‑art systems in:
#
# 1. **Generating reliable structured outputs and using external tools**
# 2. **Efficiently allocating tokens (it can over‑think simple queries and under‑think complex ones)**
# 3. **Handling languages other than Chinese/English without mixing languages**
# 4. **Being robust to prompt variations (requires careful prompt engineering)**
#
# These are the primary bottlenecks that the authors expect to address in future versions.
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
