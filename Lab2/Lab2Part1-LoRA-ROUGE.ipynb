# %% [markdown]
# # Fine-tune a Model and Evaluate it using ROUGE Metrics
#
# * We mark **TODO** in the notebook cells to indicate the place where you need to complete the missing code. You can refer to the exercises in the course repository for code examples.

# %% [markdown]
# ## Install necessary packages
#
# This is a onestep process to install necessary bitsandbytes(Alpha release) for the notebook.
# 1. Run below cell uncommenting the installation commands, after successful installation, comment back again.
# 2. Now Restart the kernel. `Kernel->Restart Kernel`
# 3. Now run the cells normally.

# %%
import sys
import os
import site
from pathlib import Path

# !echo "Installation in progress, please wait..."
# !{sys.executable} -m pip cache purge > /dev/null

# %pip install --user bitsandbytes --upgrade transformers datasets trl peft accelerate scipy sentencepiece ipywidgets evaluate rouge_score --no-warn-script-location

# !echo "Installation completed."

# Get the site-packages directory
site_packages_dir = site.getsitepackages()[0]

# add the site pkg directory where these pkgs are insalled to the top of sys.path
if not os.access(site_packages_dir, os.W_OK):
    user_site_packages_dir = site.getusersitepackages()
    if user_site_packages_dir in sys.path:
        sys.path.remove(user_site_packages_dir)
    sys.path.insert(0, user_site_packages_dir)
else:
    if site_packages_dir in sys.path:
        sys.path.remove(site_packages_dir)
    sys.path.insert(0, site_packages_dir)
# Out:
# Installation in progress, please wait...
# Requirement already satisfied: bitsandbytes in /home/exouser/.local/lib/python3.12/site-packages (0.49.2)
# Requirement already satisfied: transformers in /home/exouser/.local/lib/python3.12/site-packages (5.3.0)
# Requirement already satisfied: datasets in /home/exouser/.local/lib/python3.12/site-packages (4.8.3)
# Requirement already satisfied: trl in /home/exouser/.local/lib/python3.12/site-packages (0.29.1)
# Requirement already satisfied: peft in /home/exouser/.local/lib/python3.12/site-packages (0.18.1)
# Requirement already satisfied: accelerate in /home/exouser/.local/lib/python3.12/site-packages (1.13.0)
# Requirement already satisfied: scipy in /home/exouser/.local/lib/python3.12/site-packages (1.17.1)
# Requirement already satisfied: sentencepiece in /home/exouser/.local/lib/python3.12/site-packages (0.2.1)
# Requirement already satisfied: ipywidgets in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (8.1.8)
# Requirement already satisfied: evaluate in /home/exouser/.local/lib/python3.12/site-packages (0.4.6)
# Requirement already satisfied: rouge_score in /home/exouser/.local/lib/python3.12/site-packages (0.1.2)
# Requirement already satisfied: torch<3,>=2.3 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from bitsandbytes) (2.9.1)
# Requirement already satisfied: numpy>=1.17 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from bitsandbytes) (2.4.1)
# Requirement already satisfied: packaging>=20.9 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from bitsandbytes) (25.0)
# Requirement already satisfied: filelock in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from torch<3,>=2.3->bitsandbytes) (3.20.3)
# Requirement already satisfied: typing-extensions>=4.10.0 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from torch<3,>=2.3->bitsandbytes) (4.15.0)
# Requirement already satisfied: setuptools in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from torch<3,>=2.3->bitsandbytes) (80.9.0)
# Requirement already satisfied: sympy>=1.13.3 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from torch<3,>=2.3->bitsandbytes) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from torch<3,>=2.3->bitsandbytes) (3.6.1)
# Requirement already satisfied: jinja2 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from torch<3,>=2.3->bitsandbytes) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from torch<3,>=2.3->bitsandbytes) (2025.10.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from torch<3,>=2.3->bitsandbytes) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from torch<3,>=2.3->bitsandbytes) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from torch<3,>=2.3->bitsandbytes) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from torch<3,>=2.3->bitsandbytes) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from torch<3,>=2.3->bitsandbytes) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from torch<3,>=2.3->bitsandbytes) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from torch<3,>=2.3->bitsandbytes) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from torch<3,>=2.3->bitsandbytes) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from torch<3,>=2.3->bitsandbytes) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from torch<3,>=2.3->bitsandbytes) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from torch<3,>=2.3->bitsandbytes) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.3.20 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from torch<3,>=2.3->bitsandbytes) (3.3.20)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from torch<3,>=2.3->bitsandbytes) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from torch<3,>=2.3->bitsandbytes) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from torch<3,>=2.3->bitsandbytes) (1.13.1.3)
# Requirement already satisfied: triton==3.5.1 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from torch<3,>=2.3->bitsandbytes) (3.5.1)
# Requirement already satisfied: huggingface-hub<2.0,>=1.3.0 in /home/exouser/.local/lib/python3.12/site-packages (from transformers) (1.7.2)
# Requirement already satisfied: pyyaml>=5.1 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from transformers) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from transformers) (2025.11.3)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from transformers) (0.22.2)
# Requirement already satisfied: typer in /home/exouser/.local/lib/python3.12/site-packages (from transformers) (0.24.1)
# Requirement already satisfied: safetensors>=0.4.3 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from transformers) (0.7.0)
# Requirement already satisfied: tqdm>=4.27 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from transformers) (4.67.1)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.2 in /home/exouser/.local/lib/python3.12/site-packages (from huggingface-hub<2.0,>=1.3.0->transformers) (1.4.2)
# Requirement already satisfied: httpx<1,>=0.23.0 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from huggingface-hub<2.0,>=1.3.0->transformers) (0.28.1)
# Requirement already satisfied: anyio in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers) (4.12.1)
# Requirement already satisfied: certifi in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers) (1.0.9)
# Requirement already satisfied: idna in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers) (3.11)
# Requirement already satisfied: h11>=0.16 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers) (0.16.0)
# Requirement already satisfied: pyarrow>=21.0.0 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from datasets) (22.0.0)
# Requirement already satisfied: dill<0.4.2,>=0.3.0 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from datasets) (0.4.0)
# Requirement already satisfied: pandas in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from datasets) (2.3.3)
# Requirement already satisfied: requests>=2.32.2 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from datasets) (2.32.5)
# Requirement already satisfied: xxhash in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from datasets) (3.6.0)
# Requirement already satisfied: multiprocess<0.70.20 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from datasets) (0.70.18)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (3.13.3)
# Requirement already satisfied: psutil in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from peft) (7.2.1)
# Requirement already satisfied: comm>=0.1.3 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from ipywidgets) (0.2.3)
# Requirement already satisfied: ipython>=6.1.0 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from ipywidgets) (9.9.0)
# Requirement already satisfied: traitlets>=4.3.1 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from ipywidgets) (5.14.3)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from ipywidgets) (4.0.15)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from ipywidgets) (3.0.16)
# Requirement already satisfied: absl-py in /home/exouser/.local/lib/python3.12/site-packages (from rouge_score) (2.4.0)
# Requirement already satisfied: nltk in /home/exouser/.local/lib/python3.12/site-packages (from rouge_score) (3.9.3)
# Requirement already satisfied: six>=1.14.0 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from rouge_score) (1.17.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (1.22.0)
# Requirement already satisfied: decorator>=4.3.2 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers>=1.0.0 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets) (1.1.1)
# Requirement already satisfied: jedi>=0.18.1 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets) (0.19.2)
# Requirement already satisfied: matplotlib-inline>=0.1.5 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets) (0.2.1)
# Requirement already satisfied: pexpect>4.3 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets) (3.0.52)
# Requirement already satisfied: pygments>=2.11.0 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets) (2.19.2)
# Requirement already satisfied: stack_data>=0.6.0 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets) (0.6.3)
# Requirement already satisfied: wcwidth in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets) (0.2.14)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from jedi>=0.18.1->ipython>=6.1.0->ipywidgets) (0.8.5)
# Requirement already satisfied: ptyprocess>=0.5 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets) (0.7.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from requests>=2.32.2->datasets) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from requests>=2.32.2->datasets) (2.6.3)
# Requirement already satisfied: executing>=1.2.0 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from stack_data>=0.6.0->ipython>=6.1.0->ipywidgets) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from stack_data>=0.6.0->ipython>=6.1.0->ipywidgets) (3.0.1)
# Requirement already satisfied: pure-eval in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from stack_data>=0.6.0->ipython>=6.1.0->ipywidgets) (0.2.3)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from sympy>=1.13.3->torch<3,>=2.3->bitsandbytes) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from jinja2->torch<3,>=2.3->bitsandbytes) (3.0.3)
# Requirement already satisfied: click in /home/exouser/.local/lib/python3.12/site-packages (from nltk->rouge_score) (8.3.1)
# Requirement already satisfied: joblib in /home/exouser/.local/lib/python3.12/site-packages (from nltk->rouge_score) (1.5.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from pandas->datasets) (2025.3)
# Requirement already satisfied: shellingham>=1.3.0 in /home/exouser/.local/lib/python3.12/site-packages (from typer->transformers) (1.5.4)
# Requirement already satisfied: rich>=12.3.0 in /home/exouser/.local/lib/python3.12/site-packages (from typer->transformers) (14.3.3)
# Requirement already satisfied: annotated-doc>=0.0.2 in /home/exouser/.local/lib/python3.12/site-packages (from typer->transformers) (0.0.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/exouser/.local/lib/python3.12/site-packages (from rich>=12.3.0->typer->transformers) (4.0.0)
# Requirement already satisfied: mdurl~=0.1 in /home/exouser/.local/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich>=12.3.0->typer->transformers) (0.1.2)
# Note: you may need to restart the kernel to use updated packages.
# Installation completed.

# %% [markdown]
# ## Import necessary packages

# %%
import torch
import os

os.environ["WANDB_DISABLED"] = "true"
import transformers
from transformers import AutoTokenizer
from peft import LoraConfig
from transformers import BitsAndBytesConfig, AutoModelForCausalLM
from peft import get_peft_model, prepare_model_for_kbit_training
from datasets import load_dataset
from trl import SFTTrainer, SFTConfig
from evaluate import load
# Out:
# Using the `WANDB_DISABLED` environment variable is deprecated and will be removed in v5. Use the --report_to flag to control the integrations used for logging result (for instance --report_to none).

# %% [markdown]
# ## Login to HuggingFace

# %%
from huggingface_hub import notebook_login
notebook_login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %% [markdown]
# ## Load Gemma-2-2b-it Model from HuggingFace Hub

# %%
model_path = "google/gemma-2-2b-it"

# TODO: create tokenizer using AutoTokenizer class
# tokenizer = ...
tokenizer = AutoTokenizer.from_pretrained(model_path)

# i keep getting out of memory for some reason, looked into it and we can use QLoRA to fix it with 4 bit quant.
bnb_config=BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_quant_type="nf4",
    bnb_4bit_use_double_quant=True
)

model = AutoModelForCausalLM.from_pretrained(model_path,
                                             attn_implementation='eager',
                                             device_map="auto",
                                             quantization_config=bnb_config
                                            )
# Out:
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]

# %% [markdown]
# ## Load, Format, and Split Dataset

# %%
def process_dataset(sample):
    messages = [
        {"role": "user", "content": f"Instruction:\nSummarize the following article.\n\nInput:\n{sample['Articles']}"},
        {"role": "assistant", "content": sample['Summaries']}
    ]
    sample = tokenizer.apply_chat_template(messages, tokenize=True, return_dict=True)
    return sample

dataset = load_dataset("gopalkalpande/bbc-news-summary", split="train")
dataset = dataset.map(process_dataset)

split_dataset = dataset.train_test_split(test_size=0.1, seed=99)
train_dataset = split_dataset["train"]
validation_dataset = split_dataset["test"]

# %% [markdown]
# ## Evaluate Base Model Summaries using ROUGE Metric

# %%
rouge = load('rouge')

# initialize lists of predictions and references later used to compute rouge scores
predictions = []
references = []

# iterate through the first 15 samples
for article, abstract in zip(validation_dataset["Articles"][:15], validation_dataset["Summaries"][:15]):
    messages = [
        {"role": "user", "content": f"Instruction:\nSummarize the following article.\n\nInput:\n{article}"},
    ]
    input_ids = tokenizer.apply_chat_template(messages,
                                              tokenize=True,
                                              add_generation_prompt=True,
                                              return_tensors="pt").to("cuda")
    
    # TODO: perform model inference using the tokens in ``input_ids''
    # output =   
    output = model.generate(input_ids, max_new_tokens=150, pad_token_id=tokenizer.eos_token_id)
     
    # Remove input prompt from output
    prompt_length = input_ids.shape[1]
    answer = tokenizer.decode(output[0][prompt_length:], skip_special_tokens=True)
    
    # TODO: add one answer to the ``predictions'' list, which is later passed to rouge compute
    predictions.append(answer)
    # TODO: add one abstract to the ``references'' list, which is later passed to rouge compute
    references.append(abstract)
    
    print(100*'-')
    print("Abstract:", abstract)
    print(100*'-')
    print("Model Summary:", answer)

print(100*'-')
# TODO: compute and print out the rouge scores including rouge1, rouge2, rougeL and rougeLsum
# TODO: you can refer to https://huggingface.co/spaces/evaluate-metric/rouge/blob/main/README.md#how-to-use
# print(...)
results = rouge.compute(predictions=predictions, references=references, use_stemmer=True)

print("ROUGE 1:", results["rouge1"])
print("ROUGE 2:", results["rouge2"])
print("ROUGE L:", results["rougeL"])
print("ROUGE Lsum:", results["rougeLsum"])
print(100*'-')
# Out:
# The attention mask is not set and cannot be inferred from input because pad token is same as eos token. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# ----------------------------------------------------------------------------------------------------
# Abstract: Immigration and asylum have normally been issues politicians from the big parties have tiptoed around at election time.But, while all the parties appear to agree the time has come to properly debate and address the issue, there are already signs they will run into precisely the same problems as before.Labour has already branded the proposal unworkable but party strategists have seen the Tories seizing a poll advantage over the issue.Former union leader Sir Bill Morris has already accused both the big parties of engaging in a "bidding war about who can be nastiest to asylum seekers".The challenge for the big parties is to ensure they can engage in the debate during the cut and thrust of a general election while also avoiding that trap.That has been attacked by the Tories as too little, too late and for failing to tackle the key issue of the numbers entering the UK.That was also true at the last general election and the issue did briefly become a campaigning issue.
# ----------------------------------------------------------------------------------------------------
# Model Summary: Immigration is becoming a central issue in the upcoming UK general election, with both Labour and the Tories signaling their intention to make it a key part of their campaigns. This is driven by high voter concern about immigration and asylum, which could swing votes.
#
# The Tories are already proposing limits on immigration, quotas for asylum seekers, and processing outside the UK. Labour has criticized this, but the Tories are gaining a poll advantage on the issue.
#
# Home Secretary Charles Clarke has proposed a points system to prioritize immigrants who benefit the economy, but the Tories see it as insufficient. The Liberal Democrats have called for a Europe-wide policy, but all parties agree the time has come to address the issue.
#
# However, there are concerns that the debate
# ----------------------------------------------------------------------------------------------------
# Abstract: Labour may have abolished hunting - but that didn't stop Chancellor Gordon Brown using his Budget to fire both barrels at some of the opposition parties' core election foxes.And in Labour circles there will undoubtedly be an argument over just how good a prime minister Gordon Brown will make at some point after the next election.He did it most obviously with his increase in national insurance contributions after the 2001 election campaign during which he had pledged not to increase income tax.As always, they accused him of glossing over the facts of the "black hole" at the centre of his finances which, they claim, would ensure tax increases after the election.Labour MPs, for example, will undoubtedly now engage in a debate over exactly how redistributive - a lovely Old Labour word - this chancellor really is.So if you are a couple with children, a pensioner, a patient or a youngster, there was something pulled from Mr Brown's red box in an attempt to persuade you to stick with or switch to a New Labour government.Tory leader Michael Howard said the chancellor was up to his old trick of deliberately re-casting his forecasts to give the illusion that everything in the Treasury larder is as fresh as the day it was first stored away for future use.Specifically, it saw him attempting to slaughter the council tax as an election issue and to tear limb from limb their wider policies for pensioners and families.
# ----------------------------------------------------------------------------------------------------
# Model Summary: The article discusses Gordon Brown's Budget, highlighting his attempts to use it as a political weapon in the upcoming election. Brown targeted key groups like pensioners, families, and young people with specific policies and handouts, aiming to appeal to their concerns. While his own party celebrated the "pre-election boost," the opposition parties accused him of misleading voters with "dodgy figures" and "vote now pay later" tactics. They criticized his increased national insurance contributions and his overall economic forecasts, comparing them to the "dodgy dossier" on Iraq's weapons of mass destruction. The article concludes by noting the intense scrutiny of the budget by both the opposition and Brown's own party, with debates over council tax policies and Brown's future as a
# ----------------------------------------------------------------------------------------------------
# Abstract: Many feel that the most difficult and challenging area for the Commission will be to identify a solution for different Digital Rights Management (DRM) schemes.They have identified that many groups have defined the forms of digital media in the areas that NEM encompasses.How people receive their digital entertainment in the future could change, following the launch of an ambitious European project.The Commission wants people to be able to locate the content they desire and have it delivered seamlessly, when on the move, at home or at work, no matter who supplies the devices, network, content, or content protection scheme.What is significant is that such a large and powerful organisation has stated its desire for digital formats to be open to all and work on any gadget.Simon Perry is the editor of the Digital Lifestyles website, which covers the impact of technology on mediaThe 10-year plan brings together the work of many currently running research projects that the EC has been funding for a number of years.The European Commission is being pragmatic in its approach.
# ----------------------------------------------------------------------------------------------------
# Model Summary: The European Commission has launched the Networked & Electronic Media (NEM) initiative to shape the future of digital entertainment in Europe.  The initiative aims to create a seamless, interconnected experience for consumers, regardless of the device, network, or content provider.
#
# The NEM approach is collaborative, with companies like Nokia, Intel, and Philips pledging support.  The Commission is taking a pragmatic approach, identifying existing digital media formats and standards, and developing new ones where necessary.  This includes addressing the challenge of different Digital Rights Management (DRM) schemes, which currently hinder interoperability and restrict access to content.
#
# The NEM plan is ambitious, encompassing not just entertainment but also healthcare, energy efficiency, and smart home control.  It builds upon existing research
# ----------------------------------------------------------------------------------------------------
# Abstract: "Of course I was a bit tired in the second set."I play my best tennis when I am fired up on the court and the reason I won today was because I was able to play my natural, attacking game," he said.Monfils, who was given a wildcard into the tournament, said: "This is my first win over a top 10 player and I am delighted.But I was confident I could survive had there been a third set."
# ----------------------------------------------------------------------------------------------------
# Model Summary: French prodigy Gael Monfils, at just 18 years old, defeated French Open champion Gaston Gaudio in the first round of the Qatar Open. Monfils, a wild card entry, won 6-4 7-6 (7-4) and showcased his impressive talent, particularly his attacking game.  Meanwhile, Fabrice Santoro, the 2000 champion, defeated Thomas Johansson, while fourth seed Mikhail Youzhny lost to Rafael Nadal. Roger Federer will face Greg Rusedski in the second round.
#
# ----------------------------------------------------------------------------------------------------
# Abstract: Ms Clarkson's legal action, filed in Los Angeles Superior Court, also accuses Mr Spector of negligence and battery, alleging he "grabbed, hit, fought with and restrained" Lana Clarkson before shooting her to death.The legal action accuses Mr Spector of murdering the actress at his LA home."However, Ms Clarkson and her family understand that the fair administration of justice takes time and in light of the numerous changes Mr Spector has made in his legal defence team over the last two years, Ms Clarkson was forced to file the action before (the statute of limitations expired) on 3 February 2005."Mr Spector, known for his work with the Beatles, has claimed that Lana Clarkson committed suicide.Music producer Phil Spector is facing legal action from the mother of the actress he has been accused of killing.Donna Clarkson, whose daughter Lana was found dead in Mr Spector's home in February 2003, is seeking unspecified damages in a civil action.
# ----------------------------------------------------------------------------------------------------
# Model Summary: Phil Spector, the music producer accused of murdering actress Lana Clarkson, is facing a civil lawsuit from her mother, Donna Clarkson. Clarkson's lawsuit alleges Spector murdered her daughter and accuses him of negligence and battery. Spector denies the killing, claiming it was accidental.  The lawsuit was filed after the statute of limitations expired, and Spector's lawyers are vowing to prove his innocence at trial.  Clarkson's lawyers intend to let the criminal proceedings proceed without interference.
#
# ----------------------------------------------------------------------------------------------------
# Abstract: The system is not available commercially yet, but Motorola, the US mobile handset and infrastructure maker, held a clinic for mobile operators on HSDPA (High Speed Downlink Packet Access), a high-speed, high bandwidth technology available now.Using technology from Lucent, it will offer data speeds of 3.6Mbps from next summer on its Isle of Man 3G network, and will eventually support speeds of up to 14.4Mbps.At 3GSM, Siemens showed off a system that transmits faster mobile data.But some mobile operators are opting for a technology called Evolution, Data Optimised (EV-DO).The speeds offered by3G mobile seemed fast at the time mobile operators were paying huge sums for 3G licences.The German company said data could be transmitted at one gigabit a second - up to 20 times faster than current 3G networks.Siemens' plans for a one gigabit network may be more than a user needs today, but Christoph Caselitz, president of the mobile networks division at the firm says that: "By the time the next generation of mobile communication debuts in 2015, the need for transmission capacities for voice, data, image and multimedia is conservatively anticipated to rise by a factor of 10."Siemens - in collaboration with the Fraunhofer German-Sino Lab for Mobile Communications and the Institute for Applied Radio System Technology - has souped up mobile communications by using three transmitting and four receiving antennae, instead of the usual one.Motorola has conducted five trials of its technology and says speeds of 2.9Mbps have been recorded at the edge of an outdoor 3G cell using a single HSDPA device.Fast 3G networks are here but the focus has shifted to their evolution into a higher bandwidth service, says the Global Mobile Suppliers Association."High-Speed Downlink Packet Access (HSDPA) - sometimes called Super 3G - will be vital for profitable services like mobile internet browsing and mobile video clips," according to a report published by UK-based research consultancy Analysys.US operator Sprint ordered a broadband data upgrade to its 3G network at the end of last year.MMO2, the UK-based operator with services in the UK, Ireland and Germany, has opted for technology based on the High Speed Downlink Packet Access (HSDPA) standard.
# ----------------------------------------------------------------------------------------------------
# Model Summary: The article discusses the need for faster mobile networks to keep up with the growing demand for high-speed internet and multimedia services.
#
# **Key takeaways:**
#
# * **3G networks are not enough:** While 3G networks are available, they are not fast enough for modern internet usage.
# * **HSDPA and EV-DO are the solutions:** High-Speed Downlink Packet Access (HSDPA) and Evolution, Data Optimised (EV-DO) are technologies offering faster speeds than standard 3G.
# * **Siemens' one-gigabit system:** Siemens is developing a system that can transmit data at one gigabit per second, but it is not yet commercially available.
# * **Demand for faster speeds:**
# ----------------------------------------------------------------------------------------------------
# Abstract: Russian oil firm Yukos lied to a US court in an attempt to stop the Russian government selling off its key production unit, the court has heard.Yukos argued that since it had a US subsidiary and local bank accounts, the US court could declare it bankrupt and stop the auction of Yugansk.But Deutsche Bank - itself a target of a Yukos lawsuit - said documents had been backdated to strengthen the case.Analysts have questioned whether a US court has any jurisdiction over Russian companies, while Moscow officials have dismissed Yukos' legal wrangling as meaningless.Its lawyer, Hugh Ray, told the court that Yukos had claimed it had transferred $27m into two Texas bank accounts opened by its new US subsidiary.Yukos chief financial officer Bruce Misamore, who had moved to the US in early December to set up Yukos USA, acknowledged the point.Deutsche Bank is involved in the case because it is itself being sued by Yukos.Yukos maintains that it filed for bankruptcy in the US because it feared it would not be able to do so in Russia.It had agreed to loan to an arm of Russian state gas firm Gazprom the money to bid for Yuganskneftegaz, as the Yukos unit is formally known.By doing so, he said, the firm had intended to reinforce its US presence - and thus its chances of getting its case heard in US courts.
# ----------------------------------------------------------------------------------------------------
# Model Summary: The article details a legal battle between Russian oil firm Yukos and the Russian government over the sale of its key production unit, Yugansk. Yukos claimed it was bankrupt and sought to stop the sale, but evidence presented by Deutsche Bank, a company also involved in the case, revealed that Yukos backdated documents to strengthen its case. The sale went ahead despite a US bankruptcy court order, with an unknown shell company winning the auction for $9.4 billion. The article also discusses Yukos' claims of political persecution and its lawsuit against various companies and the Russian government.  The article concludes by highlighting the potential implications of the case for Russia's oil industry and the future of Yukos' founder, Mikhail Khodorkovsky.
# ----------------------------------------------------------------------------------------------------

# ----------------------------------------------------------------------------------------------------
# Model Summary: The article discusses the growing popularity of "casual gaming" in 2005.  Experts predict that easy-to-play, online or mobile-accessible games, like poker, pool, and puzzles, will see significant growth.
#
# While often associated with women, casual gaming is actually gender-neutral and attracts different demographics depending on the game.  Hardcore gamers, who prefer high-spec PC games, also enjoy casual games like poker and pool.
#
# The article highlights several factors driving the rise of casual gaming:
#
# * **Increased PC power and broadband access:**  More people have access to powerful PCs and high-speed internet, making casual gaming more accessible.
# * **Portable devices:**  Mobile devices and portable players
# ----------------------------------------------------------------------------------------------------
# Abstract: The BDO optimism index - a leading indicator of GDP growth two quarters ahead edged up in January to 102.5, from 102.2 in October.The only thing blighting business optimism this year will be uncertainties associated with the general election, BDO said."The UK is looking strong going into the general election, but businesses need to prepare themselves for a jolt ahead as the Bank of England reacts to growth and inflationary pressures," said Peter Hemington, partner at BDO Stoy Hayward.Optimism is at its highest since 1997 and business will reap the benefits of a continuing rise in public spending, say researchers at BDO Stoy Hayward.UK businesses are set to prosper during the next few months - but this could trigger more interest rate rises, according to a report.
# ----------------------------------------------------------------------------------------------------
# Model Summary: The UK economy is showing strong signs of growth in the lead-up to the general election in May, according to a report by BDO Stoy Hayward. Business optimism is at its highest since 1997, fueled by increased public spending and merger activity. However, the report warns that the Bank of England is likely to raise interest rates after the election due to the anticipated growth and inflationary pressures. While the economy is expected to grow by 2.9% in the second quarter of 2005, the report cautions that growth will likely slow down by the end of the year, and higher interest rates or a drop in demand could occur.
#
# ----------------------------------------------------------------------------------------------------
# Abstract: The US stock market regulator is investigating troubled insurance broker Marsh & McLennan's shareholder transactions, the firm has said.Marsh has said it is co-operating fully with the SEC investigation.Marsh is also the focus of an inquiry the New York attorney-general into whether insurers rigged the market.Since that inquiry was launched in October, Marsh has replaced its chief executive and held a boardroom shake-out to meet criticism by lessening the number of company executives on the board.Prosecutors allege that Marsh - the world's biggest insurance broker - and other US insurance firms may have fixed bids for corporate cover.The uncertainty unleashed by the scandal has prompted three credit rating agencies - Standard & Poor's, Moody's and Fitch - to downgrade Marsh in recent weeks.
# ----------------------------------------------------------------------------------------------------
# Model Summary: Marsh & McLennan, the world's largest insurance broker, is under intense scrutiny from both the Securities and Exchange Commission (SEC) and New York Attorney General Eliot Spitzer. The SEC is investigating related party transactions, including those involving the Trident Funds managed by Marsh's private equity firm. Spitzer's inquiry alleges that Marsh and other US insurance firms may have rigged bids for corporate insurance. Marsh has replaced its CEO and undergone a boardroom shake-up in response to the criticism.
#
# The scandal has led to a downgrade of Marsh's credit rating by three major credit rating agencies. Insurance analysts are now questioning Marsh's ability to maintain its strong earnings growth and the potential financial burden of settling with regulators and lawyers.
#
# ----------------------------------------------------------------------------------------------------
# ROUGE 1: 0.3965986928346949
# ROUGE 2: 0.1364450101829971
# ROUGE L: 0.20180158951596375
# ROUGE Lsum: 0.22027136219754329
# ----------------------------------------------------------------------------------------------------

# %% [markdown]
# ## Run the SFTTrainer to Fine-tune Model

# %%
finetuned_model = "gemma-2-2b-it-finetuned"

peft_config = LoraConfig(
    r=64,
    lora_alpha=32,
    lora_dropout=0.05,
    target_modules="all-linear",
    modules_to_save=["lm_head", "embed_token"],
    task_type="CAUSAL_LM",
)

if torch.cuda.is_available():
    torch.cuda.empty_cache()

# TODO: set up the trainer using SFTTrainer class
# TODO: you can refer to the gemma_xpu_finetuning.ipynb exercise
# TODO: this part is relatively long because of the arguments that need to be set
# trainer = SFTTrainer(...)

#Referencing gemma_finetuning exercise
training_args = SFTConfig(
    output_dir=finetuned_model,
    max_length=512,
    per_device_train_batch_size=1,
    gradient_accumulation_steps=8,
    gradient_checkpointing=True,
    num_train_epochs=1,
    learning_rate=2e-4,
    logging_steps=10,
    bf16=True,
)

trainer = SFTTrainer(
    model=model,
    train_dataset=train_dataset,
    eval_dataset=validation_dataset,
    args=training_args,
    peft_config=peft_config,
    processing_class=tokenizer,
)

    

model.config.use_cache = False  # silence the warnings. Please re-enable for inference!
result = trainer.train()
model.config.use_cache = True
print(result)
# Out:
# Using the `WANDB_DISABLED` environment variable is deprecated and will be removed in v5. Use the --report_to flag to control the integrations used for logging result (for instance --report_to none).
# /home/exouser/.local/lib/python3.12/site-packages/peft/tuners/tuners_utils.py:1225: UserWarning: Model has `tie_word_embeddings=True` and a tied layer is part of the adapter, but `ensure_weight_tying` is not set to True. This can lead to complications, for example when merging the adapter or converting your model to formats other than safetensors. Check the discussion here: https://github.com/huggingface/peft/issues/2777
#   warnings.warn(msg)
# The tokenizer has new PAD/BOS/EOS tokens that differ from the model config and generation config. The model config and generation config were aligned accordingly, being updated with the tokenizer's values. Updated tokens: {'eos_token_id': 1}.
#     <div>
#
#       <progress value='251' max='251' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [251/251 18:14, Epoch 1/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>10</td>
#       <td>2.186700</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>2.003500</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>2.020900</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>1.960000</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>1.950400</td>
#     </tr>
#     <tr>
#       <td>60</td>
#       <td>1.919100</td>
#     </tr>
#     <tr>
#       <td>70</td>
#       <td>1.923300</td>
#     </tr>
#     <tr>
#       <td>80</td>
#       <td>1.916900</td>
#     </tr>
#     <tr>
#       <td>90</td>
#       <td>1.823900</td>
#     </tr>
#     <tr>
#       <td>100</td>
#       <td>1.937400</td>
#     </tr>
#     <tr>
#       <td>110</td>
#       <td>1.851500</td>
#     </tr>
#     <tr>
#       <td>120</td>
#       <td>1.944100</td>
#     </tr>
#     <tr>
#       <td>130</td>
#       <td>1.882300</td>
#     </tr>
#     <tr>
#       <td>140</td>
#       <td>1.866200</td>
#     </tr>
#     <tr>
#       <td>150</td>
#       <td>1.869700</td>
#     </tr>
#     <tr>
#       <td>160</td>
#       <td>1.848200</td>
#     </tr>
#     <tr>
#       <td>170</td>
#       <td>1.859200</td>
#     </tr>
#     <tr>
#       <td>180</td>
#       <td>1.834500</td>
#     </tr>
#     <tr>
#       <td>190</td>
#       <td>1.798400</td>
#     </tr>
#     <tr>
#       <td>200</td>
#       <td>1.864500</td>
#     </tr>
#     <tr>
#       <td>210</td>
#       <td>1.805700</td>
#     </tr>
#     <tr>
#       <td>220</td>
#       <td>1.874100</td>
#     </tr>
#     <tr>
#       <td>230</td>
#       <td>1.869500</td>
#     </tr>
#     <tr>
#       <td>240</td>
#       <td>1.857900</td>
#     </tr>
#     <tr>
#       <td>250</td>
#       <td>1.802500</td>
#     </tr>
#   </tbody>
# </table><p>
# Using the `WANDB_DISABLED` environment variable is deprecated and will be removed in v5. Use the --report_to flag to control the integrations used for logging result (for instance --report_to none).
# TrainOutput(global_step=251, training_loss=1.8990026555688257, metrics={'train_runtime': 1098.9728, 'train_samples_per_second': 1.821, 'train_steps_per_second': 0.228, 'total_flos': 1.5603527866088448e+16, 'train_loss': 1.8990026555688257})

# %% [markdown]
# ## Inference Fine-tuned Model and Evaluate Summaries using ROUGE

# %%
rouge = load('rouge')

finetuned_model_path = f"{finetuned_model}/checkpoint-251" # needed to change this to match the folder in gemma-2-2b-it-finetuned/
loaded_model = AutoModelForCausalLM.from_pretrained(finetuned_model_path, device_map="cuda", quantization_config=bnb_config)
tokenizer = AutoTokenizer.from_pretrained(finetuned_model_path)

predictions = []
references = []

# TODO: compute rouge scores on the first 15 sample again.
# TODO: you can repeat the code from the earlier cells.
#

for article, abstract in zip(validation_dataset["Articles"][:15], validation_dataset["Summaries"][:15]):
    messages = [
        {"role": "user", "content": f"Instruction:\nSummarize the following article.\n\nInput:\n{article}"},
    ]
    input_ids = tokenizer.apply_chat_template(messages,
                                              tokenize=True,
                                              add_generation_prompt=True,
                                              return_tensors="pt").to("cuda")
    
    # TODO: perform model inference using the tokens in ``input_ids''
    # output =   
    output = loaded_model.generate(input_ids, max_new_tokens=150, pad_token_id=tokenizer.eos_token_id)
     
    # Remove input prompt from output
    prompt_length = input_ids.shape[1]
    answer = tokenizer.decode(output[0][prompt_length:], skip_special_tokens=True)
    
    # TODO: add one answer to the ``predictions'' list, which is later passed to rouge compute
    predictions.append(answer)
    # TODO: add one abstract to the ``references'' list, which is later passed to rouge compute
    references.append(abstract)
    
    print(100*'-')
    print("Abstract:", abstract)
    print(100*'-')
    print("Model Summary:", answer)

print(100*'-')
# TODO: compute and print out the rouge scores including rouge1, rouge2, rougeL and rougeLsum
# TODO: you can refer to https://huggingface.co/spaces/evaluate-metric/rouge/blob/main/README.md#how-to-use
# print(...)
results = rouge.compute(predictions=predictions, references=references, use_stemmer=True)

print("ROUGE 1:", results["rouge1"])
print("ROUGE 2:", results["rouge2"])
print("ROUGE L:", results["rougeL"])
print("ROUGE Lsum:", results["rougeLsum"])
print(100*'-')
# Out:
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# ----------------------------------------------------------------------------------------------------
# Abstract: Immigration and asylum have normally been issues politicians from the big parties have tiptoed around at election time.But, while all the parties appear to agree the time has come to properly debate and address the issue, there are already signs they will run into precisely the same problems as before.Labour has already branded the proposal unworkable but party strategists have seen the Tories seizing a poll advantage over the issue.Former union leader Sir Bill Morris has already accused both the big parties of engaging in a "bidding war about who can be nastiest to asylum seekers".The challenge for the big parties is to ensure they can engage in the debate during the cut and thrust of a general election while also avoiding that trap.That has been attacked by the Tories as too little, too late and for failing to tackle the key issue of the numbers entering the UK.That was also true at the last general election and the issue did briefly become a campaigning issue.
# ----------------------------------------------------------------------------------------------------
# Model Summary: The Tories are already committed to imposing annual limits on immigration, with a quota for asylum seekers and with applications processed outside the UK.That has been attacked by the Tories as too little, too late and for failing to tackle the key issue of the numbers entering the UK.The challenge for the big parties is to ensure they can engage in the debate during the cut and thrust of a general election while also avoiding that trap.The Tories have already signalled their intention of making them central to their election campaigns.The Liberal Democrats have not been drawn too deeply into the argument but have called for a Europe-wide policy on immigration.
# ----------------------------------------------------------------------------------------------------
# Abstract: Labour may have abolished hunting - but that didn't stop Chancellor Gordon Brown using his Budget to fire both barrels at some of the opposition parties' core election foxes.And in Labour circles there will undoubtedly be an argument over just how good a prime minister Gordon Brown will make at some point after the next election.He did it most obviously with his increase in national insurance contributions after the 2001 election campaign during which he had pledged not to increase income tax.As always, they accused him of glossing over the facts of the "black hole" at the centre of his finances which, they claim, would ensure tax increases after the election.Labour MPs, for example, will undoubtedly now engage in a debate over exactly how redistributive - a lovely Old Labour word - this chancellor really is.So if you are a couple with children, a pensioner, a patient or a youngster, there was something pulled from Mr Brown's red box in an attempt to persuade you to stick with or switch to a New Labour government.Tory leader Michael Howard said the chancellor was up to his old trick of deliberately re-casting his forecasts to give the illusion that everything in the Treasury larder is as fresh as the day it was first stored away for future use.Specifically, it saw him attempting to slaughter the council tax as an election issue and to tear limb from limb their wider policies for pensioners and families.
# ----------------------------------------------------------------------------------------------------
# Model Summary: Labour may have abolished hunting - but that didn't stop Chancellor Gordon Brown using his Budget to fire both barrels at some of the opposition parties' core election foxes.As Liberal Democrat leader Charles Kennedy claimed, for most families the distinction between income tax and a tax on income is meaningless.Where the chancellor mostly avoided direct electioneering, Mr Howard felt no such constraint with attacks like comparing Mr Brown's forecasts to the prime minister's forecasts on Iraq's weapons of mass destruction.As always, they accused him of glossing over the facts of the "black hole" at the centre of his finances which, they claim, would ensure tax increases after the election.He branded it a dodgy "vote now pay later" budget based on dodgy
# ----------------------------------------------------------------------------------------------------
# Abstract: Many feel that the most difficult and challenging area for the Commission will be to identify a solution for different Digital Rights Management (DRM) schemes.They have identified that many groups have defined the forms of digital media in the areas that NEM encompasses.How people receive their digital entertainment in the future could change, following the launch of an ambitious European project.The Commission wants people to be able to locate the content they desire and have it delivered seamlessly, when on the move, at home or at work, no matter who supplies the devices, network, content, or content protection scheme.What is significant is that such a large and powerful organisation has stated its desire for digital formats to be open to all and work on any gadget.Simon Perry is the editor of the Digital Lifestyles website, which covers the impact of technology on mediaThe 10-year plan brings together the work of many currently running research projects that the EC has been funding for a number of years.The European Commission is being pragmatic in its approach.
# ----------------------------------------------------------------------------------------------------
# Model Summary: The NEM approach is to take a serious look at what is available and what is in the pipeline, pick out the best, bring them together and identify where the gaps are.The NEM approach is to take a serious look at what is available and what is in the pipeline, pick out the best, bring them together and identify where the gaps are.The European Commission is being pragmatic in its approach.The 10-year plan brings together the work of many currently running research projects that the EC has been funding for a number of years.How people receive their digital entertainment in the future could change, following the launch of an ambitious European project.More than 120 experts were in Nice to share the vision of interconnected future and hear pledges
# ----------------------------------------------------------------------------------------------------
# Abstract: "Of course I was a bit tired in the second set."I play my best tennis when I am fired up on the court and the reason I won today was because I was able to play my natural, attacking game," he said.Monfils, who was given a wildcard into the tournament, said: "This is my first win over a top 10 player and I am delighted.But I was confident I could survive had there been a third set."
# ----------------------------------------------------------------------------------------------------
# Model Summary: French prodigy Gael Monfils underlined his huge promise by beating French Open champion Gaston Gaudio 6-4 7-6 (7-4) in the first round of the Qatar Open.Federer plays Greg Rusedski in the second round on Wednesday.Monfils, who was given a wildcard into the tournament, said: "This is my first win over a top 10 player and I am delighted.
# ----------------------------------------------------------------------------------------------------
# Abstract: Ms Clarkson's legal action, filed in Los Angeles Superior Court, also accuses Mr Spector of negligence and battery, alleging he "grabbed, hit, fought with and restrained" Lana Clarkson before shooting her to death.The legal action accuses Mr Spector of murdering the actress at his LA home."However, Ms Clarkson and her family understand that the fair administration of justice takes time and in light of the numerous changes Mr Spector has made in his legal defence team over the last two years, Ms Clarkson was forced to file the action before (the statute of limitations expired) on 3 February 2005."Mr Spector, known for his work with the Beatles, has claimed that Lana Clarkson committed suicide.Music producer Phil Spector is facing legal action from the mother of the actress he has been accused of killing.Donna Clarkson, whose daughter Lana was found dead in Mr Spector's home in February 2003, is seeking unspecified damages in a civil action.
# ----------------------------------------------------------------------------------------------------
# Model Summary: Ms Clarkson's legal action, filed in Los Angeles Superior Court, also accuses Mr Spector of negligence and battery, alleging he "grabbed, hit, fought with and restrained" Lana Clarkson before shooting her to death.Mr Spector, known for his work with the Beatles, has claimed that Lana Clarkson committed suicide.Mr Spector is currently free on $1m (£535,000) bail and is awaiting trial.Mr Spector, known for his work with the Beatles, has claimed that Lana Clarkson committed suicide.A Los Angeles Superior Court judge is expected to set a trial date later this month for Spector, who was indicted on murder charges in September.
# ----------------------------------------------------------------------------------------------------
# Abstract: The system is not available commercially yet, but Motorola, the US mobile handset and infrastructure maker, held a clinic for mobile operators on HSDPA (High Speed Downlink Packet Access), a high-speed, high bandwidth technology available now.Using technology from Lucent, it will offer data speeds of 3.6Mbps from next summer on its Isle of Man 3G network, and will eventually support speeds of up to 14.4Mbps.At 3GSM, Siemens showed off a system that transmits faster mobile data.But some mobile operators are opting for a technology called Evolution, Data Optimised (EV-DO).The speeds offered by3G mobile seemed fast at the time mobile operators were paying huge sums for 3G licences.The German company said data could be transmitted at one gigabit a second - up to 20 times faster than current 3G networks.Siemens' plans for a one gigabit network may be more than a user needs today, but Christoph Caselitz, president of the mobile networks division at the firm says that: "By the time the next generation of mobile communication debuts in 2015, the need for transmission capacities for voice, data, image and multimedia is conservatively anticipated to rise by a factor of 10."Siemens - in collaboration with the Fraunhofer German-Sino Lab for Mobile Communications and the Institute for Applied Radio System Technology - has souped up mobile communications by using three transmitting and four receiving antennae, instead of the usual one.Motorola has conducted five trials of its technology and says speeds of 2.9Mbps have been recorded at the edge of an outdoor 3G cell using a single HSDPA device.Fast 3G networks are here but the focus has shifted to their evolution into a higher bandwidth service, says the Global Mobile Suppliers Association."High-Speed Downlink Packet Access (HSDPA) - sometimes called Super 3G - will be vital for profitable services like mobile internet browsing and mobile video clips," according to a report published by UK-based research consultancy Analysys.US operator Sprint ordered a broadband data upgrade to its 3G network at the end of last year.MMO2, the UK-based operator with services in the UK, Ireland and Germany, has opted for technology based on the High Speed Downlink Packet Access (HSDPA) standard.
# ----------------------------------------------------------------------------------------------------
# Model Summary: The German company said data could be transmitted at one gigabit a second - up to 20 times faster than current 3G networks.A number of companies are developing the technology.If they aren't, those lucrative "power users", such as computer geeks and busy business people will avoid them for all but the most urgent tasks, reducing the potential revenues available to mobile operators.The German company said data could be transmitted at one gigabit a second - up to 20 times faster than current 3G networks.The system is not available commercially yet, but Motorola, the US mobile handset and infrastructure maker, held a clinic for mobile operators on HSDPA (High Speed Downlink Packet Access).The speeds offered by3
# ----------------------------------------------------------------------------------------------------
# Abstract: Russian oil firm Yukos lied to a US court in an attempt to stop the Russian government selling off its key production unit, the court has heard.Yukos argued that since it had a US subsidiary and local bank accounts, the US court could declare it bankrupt and stop the auction of Yugansk.But Deutsche Bank - itself a target of a Yukos lawsuit - said documents had been backdated to strengthen the case.Analysts have questioned whether a US court has any jurisdiction over Russian companies, while Moscow officials have dismissed Yukos' legal wrangling as meaningless.Its lawyer, Hugh Ray, told the court that Yukos had claimed it had transferred $27m into two Texas bank accounts opened by its new US subsidiary.Yukos chief financial officer Bruce Misamore, who had moved to the US in early December to set up Yukos USA, acknowledged the point.Deutsche Bank is involved in the case because it is itself being sued by Yukos.Yukos maintains that it filed for bankruptcy in the US because it feared it would not be able to do so in Russia.It had agreed to loan to an arm of Russian state gas firm Gazprom the money to bid for Yuganskneftegaz, as the Yukos unit is formally known.By doing so, he said, the firm had intended to reinforce its US presence - and thus its chances of getting its case heard in US courts.
# ----------------------------------------------------------------------------------------------------
# Model Summary: Yukos maintains that it filed for bankruptcy in the US because it feared it would not be able to do so in Russia.Yukos chief financial officer Bruce Misamore, who had moved to the US in early December to set up Yukos USA, acknowledged the point.But he said that the papers documenting the transaction were not drawn up till weeks after Yukos made its bankruptcy application on 14 December, and then backdated.Yukos is currently suing four companies - Gazprom, its unit Gazpromneft, Rosneft and the shell company which won the bidding - for their part in Yugansk's disposal.Yukos claims that the rights of its shareholders have been ignored and that is has been punished for the political ambitions
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# Model Summary: Games aimed at "casual players" are set to be even bigger in 2005, according to industry experts.The panel also insisted that casual gamers were not just women, a common misconception which pervades current thinking about gamer demographics.With the growth of powerful PC technology and ownership, broadband take-up, portable players and mobile devices, as well as interactive TV, casual gaming is shaping up to be big business in 2005, according to the panel.The panel said its figures suggested that sports-based games attracted 90% of 18 to 24-year-old males, while puzzle games were played by 80% of females.With more people finding more to do with their gadgets
# ----------------------------------------------------------------------------------------------------
# Abstract: The BDO optimism index - a leading indicator of GDP growth two quarters ahead edged up in January to 102.5, from 102.2 in October.The only thing blighting business optimism this year will be uncertainties associated with the general election, BDO said."The UK is looking strong going into the general election, but businesses need to prepare themselves for a jolt ahead as the Bank of England reacts to growth and inflationary pressures," said Peter Hemington, partner at BDO Stoy Hayward.Optimism is at its highest since 1997 and business will reap the benefits of a continuing rise in public spending, say researchers at BDO Stoy Hayward.UK businesses are set to prosper during the next few months - but this could trigger more interest rate rises, according to a report.
# ----------------------------------------------------------------------------------------------------
# Model Summary: UK businesses are set to prosper during the next few months - but this could trigger more interest rate rises, according to a report.The Bank of England is expected to keep rates on hold this week - but they could go up later in the year.The only thing blighting business optimism this year will be uncertainties associated with the general election, BDO said.Its BDO's output index - which predicts GDP movements a quarter in advance - remained at 100.8 for January, implying GDP growth at 2.9% in the second quarter of 2005.The output index is being held back by recent interest rate rises, sterling's strength against the dollar and high oil prices, the group noted.
# ----------------------------------------------------------------------------------------------------
# Abstract: The US stock market regulator is investigating troubled insurance broker Marsh & McLennan's shareholder transactions, the firm has said.Marsh has said it is co-operating fully with the SEC investigation.Marsh is also the focus of an inquiry the New York attorney-general into whether insurers rigged the market.Since that inquiry was launched in October, Marsh has replaced its chief executive and held a boardroom shake-out to meet criticism by lessening the number of company executives on the board.Prosecutors allege that Marsh - the world's biggest insurance broker - and other US insurance firms may have fixed bids for corporate cover.The uncertainty unleashed by the scandal has prompted three credit rating agencies - Standard & Poor's, Moody's and Fitch - to downgrade Marsh in recent weeks.
# ----------------------------------------------------------------------------------------------------
# Model Summary: The US stock market regulator is investigating troubled insurance broker Marsh & McLennan's shareholder transactions, the firm has said.Marsh is also the focus of an inquiry the New York attorney-general into whether insurers rigged the market.Since that inquiry was launched in October, Marsh has replaced its chief executive and held a boardroom shake-out to meet criticism by lessening the number of company executives on the board.Marsh's new chief executive, Michael Cherkasky, is trying to negotiate a settlement with Mr Spitzer.Marsh has said it is co-operating fully with the SEC investigation.
# ----------------------------------------------------------------------------------------------------
# ROUGE 1: 0.5195078874135872
# ROUGE 2: 0.37793895492251395
# ROUGE L: 0.362467701370887
# ROUGE Lsum: 0.3622802973537546
# ----------------------------------------------------------------------------------------------------
